# %%
# !pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 7.6/7.6 MB 6.2 MB/s eta 0:00:00
# ...
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: C:\Users\Admin\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

# %%
methods = ['edmundson', 'kl', 'lexrank', 'lsa', 'luhn', 'textrank']
recall_scores = [0.350316231, 0.258894711, 0.401570106, 0.398594349, 0.482068606, 0.500146194]
precision_scores = [1, 1, 1, 1, 1, 1]
f1_scores = [0.504497843, 0.399845666, 0.558923355, 0.552786934, 0.637921462, 0.655285643]

plt.figure(figsize=(10, 6))
plt.plot(methods, recall_scores, 'r', label='Recall')
plt.plot(methods, precision_scores, 'g', label='Precision')
plt.plot(methods, f1_scores, 'b', label='F1-score')

plt.xlabel('Phương pháp tóm tắt văn bản')
plt.ylabel('Kết quả độ chính xác')
plt.title('Biểu đồ ROUGE-1')

plt.legend()
plt.grid(True)
plt.show()
